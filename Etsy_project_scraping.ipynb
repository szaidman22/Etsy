# %%
import requests
from bs4 import BeautifulSoup
import bleach
import pprint
import pandas as pd

# %%
#try looping over multiple web pages
#THIS WORKS!!!! THIS IS GOOD!!!
#add piece that automatically stops when all listings are done

listing_info = []
for i in range(1,2):      # Number of pages plus one 
    url = "https://www.etsy.com/search/vintage/clothing/womens-clothing?q=womens+vintage+clothing&locationQuery=5332921&explicit=1&ref=pagination&page={}".format(i)
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    results = soup.find(id="content")
    job_elems = results.find_all(class_= 'organic-impression display-inline-block listing-link ')
    links_stage = []
    link_elem = []
    for job_elem in job_elems:
        title_elem = job_elem.find(class_='text-gray text-truncate mb-xs-0 text-body')
        title_elem = bleach.clean(title_elem, tags=[], strip=True).strip()
        price_elem = job_elem.find(class_='currency-value')
        price_elem = bleach.clean(price_elem, tags=[], strip=True).strip()
        links_stage.append(job_elem)
        for x in links_stage:
            link_elem = (x.get('href'))
            page = requests.get((x.get('href')))
            soup = BeautifulSoup(page.content, 'html.parser')
            results = soup.find(id="content")  
            place_stage = results.find(class_="display-inline-block text-body text-gray-lightest")
            place_elem = bleach.clean(place_stage, tags=[], strip=True).strip()
            
        listing_info.append((title_elem,price_elem,"Berkeley, CA", link_elem, place_elem))
    print(len(listing_info))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-117-3877545ef6a5> in <module>()
#      21             link_elem = (x.get('href'))
#      22             page = requests.get((x.get('href')))
# ---> 23             soup = BeautifulSoup(page.content, 'html.parser')
#      24             results = soup.find(id="content")
#      25             place_stage = results.find(class_="display-inline-block text-body text-gray-lightest")
#
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     226             self.reset()
#     227             try:
# --> 228                 self._feed()
#     229                 break
#     230             except ParserRejectedMarkup:
#
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py in _feed(self)
#     287         self.builder.reset()
#     288
# --> 289         self.builder.feed(self.markup)
#     290         # Close out any unfinished strings and close all the open tags.
#     291         self.endData()
#
# /anaconda3/lib/python3.6/site-packages/bs4/builder/_htmlparser.py in feed(self, markup)
#     213         parser.soup = self.soup
#     214         try:
# --> 215             parser.feed(markup)
#     216         except HTMLParseError as e:
#     217             warnings.warn(RuntimeWarning(
#
# /anaconda3/lib/python3.6/html/parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# /anaconda3/lib/python3.6/html/parser.py in goahead(self, end)
#     169             if startswith('<', i):
#     170                 if starttagopen.match(rawdata, i): # < + letter
# --> 171                     k = self.parse_starttag(i)
#     172                 elif startswith("</", i):
#     173                     k = self.parse_endtag(i)
#
# /anaconda3/lib/python3.6/html/parser.py in parse_starttag(self, i)
#     343             self.handle_startendtag(tag, attrs)
#     344         else:
# --> 345             self.handle_starttag(tag, attrs)
#     346             if tag in self.CDATA_CONTENT_ELEMENTS:
#     347                 self.set_cdata_mode(tag)
#
# /anaconda3/lib/python3.6/site-packages/bs4/builder/_htmlparser.py in handle_starttag(self, name, attrs, handle_empty_element)
#      88             attrvalue = '""'
#      89         #print "START", name
# ---> 90         tag = self.soup.handle_starttag(name, None, None, attr_dict)
#      91         if tag and tag.is_empty_element and handle_empty_element:
#      92             # Unlike other parsers, html.parser doesn't send separate end tag
#
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py in handle_starttag(self, name, namespace, nsprefix, attrs)
#     455
#     456         # print "Start tag %s: %s" % (name, attrs)
# --> 457         self.endData()
#     458
#     459         if (self.parse_only and len(self.tagStack) <= 1
#
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py in endData(self, containerClass)
#     337     def endData(self, containerClass=NavigableString):
#     338         if self.current_data:
# --> 339             current_data = ''.join(self.current_data)
#     340             # If whitespace is not preserved, and this string contains
#     341             # nothing but ASCII spaces, replace it with a single space
#
# KeyboardInterrupt:

# %%
listing_info
# Out:
# [('Vintage Clothing, Tweed Jacket',
#   '42.00',
#   'Berkeley, CA',
#   'https://www.etsy.com/listing/767153535/vintage-clothing-tweed-jacket?ga_order=most_relevant&ga_search_type=vintage&ga_view_type=gallery&ga_search_query=womens+vintage+clothing&ref=sr_gallery-1-1&organic_search_click=1&cns=1',
#   'Los Angeles, California'),
#  ('womens 70s shirts white floral blouse vintage hippie boho top womens 70s clothing',
#   '46.00',
#   'Berkeley, CA',
#   'https://www.etsy.com/listing/778406827/womens-70s-shirts-white-floral-blouse?ga_order=most_relevant&ga_search_type=vintage&ga_view_type=gallery&ga_search_query=womens+vintage+clothing&ref=sr_gallery-1-2&organic_search_click=1&frs=1&cns=1',
#   'Los Angeles, California'),
#  ('Vintage Clothing, Satin Ombre Pencil Skirt',
#   '15.00',
#   'Berkeley, CA',
#   'https://www.etsy.com/listing/755616696/vintage-clothing-satin-ombre-pencil?ga_order=most_relevant&ga_search_type=vintage&ga_view_type=gallery&ga_search_query=womens+vintage+clothing&ref=sr_gallery-1-3&organic_search_click=1',
#   'Los Angeles, California'),
#  ("50s 60s Angora Knit Beaded Blouse - Small | Vintage Clothing, Women's Clothing",
#   '18.00',
#   'Berkeley, CA',
#   'https://www.etsy.com/listing/695295312/50s-60s-angora-knit-beaded-blouse-small?ga_order=most_relevant&ga_search_type=vintage&ga_view_type=gallery&ga_search_query=womens+vintage+clothing&ref=sr_gallery-1-4&organic_search_click=1&frs=1&cns=1',
#   'Pasadena, California'),
#  ('Vintage Clothing, Western Maxi Skirt with matching Belt',
#   '42.00',
#   'Berkeley, CA',
#   'https://www.etsy.com/listing
# 7   https://www.etsy.com/listing/757846558/70s-str...     Pasadena, California
# 8   https://www.etsy.com/listing/755046082/vintage...  San Anselmo, California
# 9   https://www.etsy.com/listing/750389338/1960s-s...   Long Beach, California
# 10  https://www.etsy.com/listing/751025804/plaid-l...       Clovis, California
# 11  https://www.etsy.com/listing/757584862/vintage...     Pasadena, California
# 12  https://www.etsy.com/listing/767157673/vintage...  Los Angeles, California
# 13  https://www.etsy.com/listing/757845458/80s-sal...     Pasadena, California

# %%
listing_data.columns

# %% [markdown]
# ### Getting exact place takes way way too long so will probably have to sample from different cities

# %%
listing_info = []
for i in range(1,2):      # Number of pages plus one 
    url = "https://www.etsy.com/search/vintage/clothing/womens-clothing?q=womens+vintage+clothing&locationQuery=5332921&explicit=1&ref=pagination&page={}".format(i)
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    results = soup.find(id="content")
    job_elems = results.find_all(class_= 'organic-impression display-inline-block listing-link ')
    links_stage = []
    link_elem = []
    for job_elem in job_elems:
        title_elem = job_elem.find(class_='text-gray text-truncate mb-xs-0 text-body')
        title_elem = bleach.clean(title_elem, tags=[], strip=True).strip()
        price_elem = job_elem.find(class_='currency-value')
        price_elem = bleach.clean(price_elem, tags=[], strip=True).strip()
        links_stage.append(job_elem)
        for x in links_stage:
            link_elem = (x.get('href'))
        listing_info.append((title_elem,price_elem,"California", link_elem))
    print(len(listing_info))
# Out:
# 48

# %%
cities = ["Alameda","El Cerrito","Mountain View","San Leandro","Albany","Emeryville","Napa"]

listing_info = []
for i in range(1,2):      # Number of pages plus one 
    url = "https://www.etsy.com/search/vintage/clothing/womens-clothing?q=womens+vintage+clothing&locationQuery=5332921&explicit=1&ref=pagination&page={}".format(i)
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    results = soup.find(id="content")
    job_elems = results.find_all(class_= 'organic-impression display-inline-block listing-link ')
    links_stage = []
    link_elem = []
    for job_elem in job_elems:
        title_elem = job_elem.find(class_='text-gray text-truncate mb-xs-0 text-body')
        title_elem = bleach.clean(title_elem, tags=[], strip=True).strip()
        price_elem = job_elem.find(class_='currency-value')
        price_elem = bleach.clean(price_elem, tags=[], strip=True).strip()
        links_stage.append(job_elem)
        for x in links_stage:
            link_elem = (x.get('href'))
        listing_info.append((title_elem,price_elem,"California", link_elem))
    print(len(listing_info))
# Out:
# ['Alameda',
#  'El Cerrito',
#  'Mountain View',
#  'San Leandro',
#  'Albany',
#  'Emeryville',
#  'Napa']

# %%
San Mateo
American Canyon
Fairfax
Newark
San Pablo
Antioch
Fairfield
Novato
San Rafael
Atherton
Foster City
Oakland
San Ramon
Belmont

# %% [markdown]
# ## Oakland

# %%
#oakland: https://www.etsy.com/search/vintage/clothing/womens-clothing?q=womens+vintage+clothing&locationQuery=5378538&explicit=1&ref=pagination&page=2        
        
listing_info = []
for i in range(1,108):      # Number of pages plus one 
    url = "https://www.etsy.com/search/vintage/clothing/womens-clothing?q=womens+vintage+clothing&locationQuery=5378538&explicit=1&ref=pagination&page={}".format(i)
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    results = soup.find(id="content")
    job_elems = results.find_all(class_= 'organic-impression display-inline-block listing-link ')
    links_stage = []
   # link_elem = []
    for job_elem in job_elems:
        title_elem = job_elem.find(class_='text-gray text-truncate mb-xs-0 text-body')
        title_elem = bleach.clean(title_elem, tags=[], strip=True).strip()
        price_elem = job_elem.find(class_='currency-value')
        price_elem = bleach.clean(price_elem, tags=[], strip=True).strip()
       # links_stage.append(job_elem)
       # for x in links_stage:
          #  link_elem = (x.get('href'))
        listing_info.append((title_elem,price_elem,"Oakland", "California"))
    print(len(listing_info))

columns = ['Description','Price','City','State']
listing_data = pd.DataFrame(listing_info,columns=columns)
oakland_listings = listing_data
# Out:
# 48
# 96
# 144
# 192
# 240
# 288
# 336
# 384
# 432
# 480
# 528
# 576
# 624
# 672
# 720
# 768
# 800
# 848
# 896
# 944
# 992
# 1040
# 1088
# 1136
# 1184
# 1232
# 1280
# 1328
# 1376
# 1424
# 1472
# 1520
# 1568
# 1616
# 1664
# 1712
# 1760
# 1808
# 1856
# 1904
# 1952
# 2000
# 2048
# 2096
# 2144
# 2192
# 2240
# 2288
# 2336
# 2384
# 2432
# 2480
# 2528
# 2576
# 2624
# 2672
# 2720
# 2768
# 2816
# 2864
# 2912
# 2960
# 3008
# 3056
# 3104
# 3152
# 3200
# 3248
# 3296
# 3344
# 3392
# 3440
# 3488
# 3536
# 3584
# 3632
# 3680
# 3728
# 3776
# 3824
# 3872
# 3920
# 3968
# 4016
# 4064
# 4112
# 4160
# 4208
# 4256
# 4304
# 4352
# 4400
# 4448
# 4496
# 4544
# 4592
# 4640
# 4688
# 4736
# 4784
# 4832
# 4880
# 4928
# 4976
# 5024
# 5072
# 5082

# %%
oakland_listings = listing_data

# %%
oakland_listings['Region'] = 'Northern California'

# %%
oakland_listings.head()
# Out:
#                                          Description   Price     City  \
# 0          Mickey Mouse Disney 1990's Vintage Tshirt   25.00  Oakland
# 1  Vintage Esprit Pastel Long Sleeve Button Up Pa...   78.95  Oakland
# 2  1910s Art Nouveau Dress | Vintage Teens Edward...  185.00  Oakland
# 3  Vintage 1990s Olive Green Velveteen Quilted Bo...   22.50  Oakland
# 4  vintage | grandma | sweater | 70s | mustard ye...   40.00  Oakland
#
#         State               Region
# 0  California  Northern California
# 1  California  Northern California
# 2  California  Northern California
# 3  California  Northern California
# 4  California  Northern California

# %%
#San Francisco: https://www.etsy.com/search/vintage/clothing/womens-clothing?q=womens+vintage+clothing&locationQuery=5391959&explicit=1&ref=pagination&page=2
        
listing_info = []
for i in range(1,148):      # Number of pages plus one 
    url = "https://www.etsy.com/search/vintage/clothing/womens-clothing?q=womens+vintage+clothing&locationQuery=5391959&explicit=1&ref=pagination&page={}".format(i)
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    results = soup.find(id="content")
    job_elems = results.find_all(class_= 'organic-impression display-inline-block listing-link ')
    links_stage = []
   # link_elem = []
    for job_elem in job_elems:
        title_elem = job_elem.find(class_='text-gray text-truncate mb-xs-0 text-body')
        title_elem = bleach.clean(title_elem, tags=[], strip=True).strip()
        price_elem = job_elem.find(class_='currency-value')
        price_elem = bleach.clean(price_elem, tags=[], strip=True).strip()
       # links_stage.append(job_elem)
       # for x in links_stage:
          #  link_elem = (x.get('href'))
        listing_info.append((title_elem,price_elem,"San Francisco", "California","Northern California"))
    print(len(listing_info))

columns = ['Description','Price','City','State','Region']
listing_data = pd.DataFrame(listing_info,columns=columns)
sanfrancisco_listings = listing_data
sanfrancisco_listings.head()
# Out:
# 48
# 96
# 144
# 192
# 240
# 288
# 336
# 384
# 432
# 480
# 528
# 576
# 624
# 672
# 720
# 768
# 800
# 848
# 896
# 944
# 992
# 1040
# 1088
# 1136
# 1184
# 1232
# 1280
# 1328
# 1376
# 1424
# 1472
# 1520
# 1568
# 1616
# 1664
# 1712
# 1760
# 1808
# 1856
# 1904
# 1952
# 2000
# 2048
# 2096
# 2144
# 2192
# 2240
# 2288
# 2336
# 2384
# 2432
# 2480
# 2528
# 2576
# 2624
# 2672
# 2720
# 2768
# 2816
# 2864
# 2912
# 2960
# 3008
# 3056
# 3104
# 3152
# 3200
# 3248
# 3296
# 3344
# 3392
# 3440
# 3488
# 3536
# 3584
# 3632
# 3680
# 3728
# 3776
# 3824
# 3872
# 3920
# 3968
# 4016
# 4064
# 4112
# 4160
# 4208
# 4256
# 4304
# 4352
# 4400
# 4448
# 4496
# 4544
# 4592
# 4640
# 4688
# 4736
# 4784
# 4832
# 4880
# 4928
# 4976
# 5024
# 5072
# 5120
# 5168
# 5216
# 5264
# 5312
# 5360
# 5408
# 5456
# 5504
# 5552
# 5600
# 5648
# 5696
# 5744
# 5792
# 5840
# 5888
# 5936
# 5984
# 6032
# 6080
# 6128
# 6176
# 6224
# 6272
# 6320
# 6368
# 6416
# 6464
# 6512
# 6560
# 6608
# 6656
# 6704
# 6752
# 6800
# 6848
# 6896
# 6944
# 6959
# 6959
#                                          Description   Price           City  \
# 0                         Vintage 1970s Prarie Skirt   30.00  San Francisco
# 1  Vintage Black Leather Motorcycle Jacket | Unis...  100.00  San Francisco
# 2  Velvet Victoriana Mini Dress | vintage dress 1...   82.00  San Francisco
# 3  1950s Dalton cashmere cardigan small | vintage...  122.00  San Francisco
# 4                 Vintage Levi's 501 Dark Wash Jeans   48.00  San Francisco
#
#         State               Region
# 0  California  Northern California
# 1  California  Northern California
# 2  California  Northern California
# 3  California  Northern California
# 4  California  Northern California

# %%
#Santa Cruz: https://www.etsy.com/search/vintage/clothing/womens-clothing?q=womens+vintage+clothing&locationQuery=5393052&explicit=1&ref=pagination&page=2
        
listing_info = []
for i in range(1,31):      # Number of pages plus one 
    url = "https://www.etsy.com/search/vintage/clothing/womens-clothing?q=womens+vintage+clothing&locationQuery=5393052&explicit=1&ref=pagination&page={}".format(i)
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    results = soup.find(id="content")
    job_elems = results.find_all(class_= 'organic-impression display-inline-block listing-link ')
    links_stage = []
   # link_elem = []
    for job_elem in job_elems:
        title_elem = job_elem.find(class_='text-gray text-truncate mb-xs-0 text-body')
        title_elem = bleach.clean(title_elem, tags=[], strip=True).strip()
        price_elem = job_elem.find(class_='currency-value')
        price_elem = bleach.clean(price_elem, tags=[], strip=True).strip()
       # links_stage.append(job_elem)
       # for x in links_stage:
          #  link_elem = (x.get('href'))
        listing_info.append((title_elem,price_elem,"Santa Cruz", "California"))
    print(len(listing_info))

columns = ['Description','Price','City','State']
listing_data = pd.DataFrame(listing_info,columns=columns)
santacruz_listings = listing_data
santacruz_listings.head()
# Out:
# 48
# 96
# 144
# 192
# 240
# 288
# 336
# 384
# 432
# 480
# 528
# 576
# 624
# 672
# 720
# 768
# 800
# 848
# 896
# 944
# 992
# 1040
# 1088
# 1136
# 1184
# 1232
# 1280
# 1328
# 1376
# 1424
#                                          Description  Price        City  \
# 0  90s Brown Tweed Textured Poly Wash N Wear Trou...  39.60  Santa Cruz
# 1  50s Beaded Cardigan Vintage Blairmoor Original...  47.00  Santa Cruz
# 2               Vintage Gunnies Quilted Denim Jacket  36.00  Santa Cruz
# 3                         Vintage Pendleton Cardigan  35.00  Santa Cruz
# 4  90s High Waist Wash and Wear Black Grid Pleate...  36.00  Santa Cruz
#
#         State
# 0  California
# 1  California
# 2  California
# 3  California
# 4  California

# %%
#Sacramento: https://www.etsy.com/search/vintage/clothing/womens-clothing?q=womens+vintage+clothing&locationQuery=5389489&explicit=1&ref=pagination&page=2

        
listing_info = []
for i in range(1,31):      # Number of pages plus one 
    url = "https://www.etsy.com/search/vintage/clothing/womens-clothing?q=womens+vintage+clothing&locationQuery=5389489&explicit=1&ref=pagination&page={}".format(i)
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    results = soup.find(id="content")
    job_elems = results.find_all(class_= 'organic-impression display-inline-block listing-link ')
    links_stage = []
   # link_elem = []
    for job_elem in job_elems:
        title_elem = job_elem.find(class_='text-gray text-truncate mb-xs-0 text-body')
        title_elem = bleach.clean(title_elem, tags=[], strip=True).strip()
        price_elem = job_elem.find(class_='currency-value')
        price_elem = bleach.clean(price_elem, tags=[], strip=True).strip()
       # links_stage.append(job_elem)
       # for x in links_stage:
          #  link_elem = (x.get('href'))
        listing_info.append((title_elem,price_elem,"Sacramento", "California"))
    print(len(listing_info))

columns = ['Description','Price','City','State']
listing_data = pd.DataFrame(listing_info,columns=columns)
sacramento_listings = listing_data
sacramento_listings.head()
# Out:
# 48
# 96
# 144
# 192
# 240
# 288
# 336
# 384
# 432
# 480
# 528
# 576
# 624
# 672
# 720
# 768
# 800
# 848
# 896
# 944
# 992
# 1040
# 1088
# 1136
# 1184
# 1232
# 1280
# 1328
# 1376
# 1424
https://www.etsy.com/search/vintage/clothing/womens-clothing?q=womens+vintage+clothing&locationQuery=5380668&explicit=1&ref=pagination&page=2

listing_info = []
for i in range(1,22):      # Number of pages plus one 
    url = "https://www.etsy.com/search/vintage/clothing/womens-clothing?q=womens+vintage+clothing&locationQuery=5380668&explicit=1&ref=pagination&page={}".format(i)
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    results = soup.find(id="content")
    job_elems = results.find_all(class_= 'organic-impression display-inline-block listing-link ')
    links_stage = []
   # link_elem = []
    for job_elem in job_elems:
        title_elem = job_elem.find(class_='text-gray text-truncate mb-xs-0 text-body')
        title_elem = bleach.clean(title_elem, tags=[], strip=True).strip()
        price_elem = job_elem.find(class_='currency-value')
        price_elem = bleach.clean(price_elem, tags=[], strip=True).strip()
       # links_stage.append(job_elem)
       # for x in links_stage:
          #  link_elem = (x.get('href'))
        listing_info.append((title_elem,price_elem,"Palm Springs", "California","Southern California"))
    print(len(listing_info))

columns = ['Description','Price','City','State','Region']
listing_data = pd.DataFrame(listing_info,columns=columns)
palmsprings_listings = listing_data
palmsprings_listings.head()
# Out:
# 48
# 96
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-0b6a66889508> in <module>()
#       5     url = "https://www.etsy.com/search/vintage/clothing/womens-clothing?q=womens+vintage+clothing&locationQuery=5380668&explicit=1&ref=pagination&page={}".format(i)
#       6     page = requests.get(url)
# ----> 7     soup = BeautifulSoup(page.content, 'html.parser')
#       8     results = soup.find(id="content")
#       9     job_elems = results.find_all(class_= 'organic-impression display-inline-block listing-link ')
#
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     226             self.reset()
#     227             try:
# --> 228                 self._feed()
#     229                 break
#     230             except ParserRejectedMarkup:
#
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py in _feed(self)
#     287         self.builder.reset()
#     288
# --> 289         self.builder.feed(self.markup)
#     290         # Close out any unfinished strings and close all the open tags.
#     291         self.endData()
#
# /anaconda3/lib/python3.6/site-packages/bs4/builder/_htmlparser.py in feed(self, markup)
#     213         parser.soup = self.soup
#     214         try:
# --> 215             parser.feed(markup)
#     216         except HTMLParseError as e:
#     217             warnings.warn(RuntimeWarning(
#
# /anaconda3/lib/python3.6/html/parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# /anaconda3/lib/python3.6/html/parser.py in goahead(self, end)
#     169             if startswith('<', i):
#     170                 if starttagopen.match(rawdata, i): # < + letter
# --> 171                     k = self.parse_starttag(i)
#     172                 elif startswith("</", i):
#     173                     k = self.parse_endtag(i)
#
# /anaconda3/lib/python3.6/html/parser.py in parse_starttag(self, i)
#     314         self.lasttag = tag = match.group(1).lower()
#     315         while k < endpos:
# --> 316             m = attrfind_tolerant.match(rawdata, k)
#     317             if not m:
#     318                 break
#
# KeyboardInterrupt:

# %%
# Brooklyn: https://www.etsy.com/search/vintage/clothing/womens-clothing?q=womens+vintage+clothing&locationQuery=5110302&explicit=1&ref=pagination&page=2

listing_info = []
for i in range(1,246):      # Number of pages plus one 
    url = "https://www.etsy.com/search/vintage/clothing/womens-clothing?q=womens+vintage+clothing&locationQuery=5110302&explicit=1&ref=pagination&page={}".format(i)
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    results = soup.find(id="content")
    job_elems = results.find_all(class_= 'organic-impression display-inline-block listing-link ')
    links_stage = []
   # link_elem = []
    for job_elem in job_elems:
        title_elem = job_elem.find(class_='text-gray text-truncate mb-xs-0 text-body')
        title_elem = bleach.clean(title_elem, tags=[], strip=True).strip()
        price_elem = job_elem.find(class_='currency-value')
        price_elem = bleach.clean(price_elem, tags=[], strip=True).strip()
       # links_stage.append(job_elem)
       # for x in links_stage:
          #  link_elem = (x.get('href'))
        listing_info.append((title_elem,price_elem,"Brooklyn", "New York","Eastern US"))
    print(len(listing_info))

columns = ['Description','Price','City','State','Region']
listing_data = pd.DataFrame(listing_info,columns=columns)
brooklyn_listings = listing_data
brooklyn_listings.head()
# Out:
# 48
# 96
# 144
# 192
# 240
# 288
# 336
# 384
# 432
# 480
# 528
# 576
# 624
# 672
# 720
# 768
# 800
# 848
# 896
# 944
# 992
# 1040
# 1088
# 1136
# 1184
# 1232
# 1280
# 1328
# 1376
# 1424
# 1472
# 1520
# 1568
# 1616
# 1664
# 1712
# 1760
# 1808
# 1856
# 1904
# 1952
# 2000
# 2048
# 2096
# 2144
# 2192
# 2240
# 2288
# 2336
# 2384
# 2432
# 2480
# 2528
# 2576
# 2624
# 2672
# 2720
# 2768
# 2816
# 2864
# 2912
# 2960
# 3008
# 3056
# 3104
# 3152
# 3200
# 3248
# 3296
# 3344
# 3392
# 3440
# 3488
# 3536
# 3584
# 3632
# 3680
# 3728
# 3776
# 3824
# 3872
# 3920
# 3968
# 4016
# 4064
# 4112
# 4160
# 4208
# 4256
# 4304
# 4352
# 4400
# 4448
# 4496
# 4544
# 4592
# 4640
# 4688
# 4736
# 4784
# 4832
# 4880
# 4928
# 4976
# 5024
# 5072
# 5120
# 5168
# 5216
# 5264
# 5312
# 5360
# 5408
# 5456
# 5504
# 5552
# 5600
# 5648
# 5696
# 5744
# 5792
# 5840
# 5888
# 5936
# 5984
# 6032
# 6080
# 6128
# 6176
# 6224
# 6272
# 6320
# 6368
# 6416
# 6464
# 6512
# 6560
# 6608
# 6656
# 6704
# 6752
# 6800
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-ccd9a17adf6b> in <module>()
#       7     soup = BeautifulSoup(page.content, 'html.parser')
#       8     results = soup.find(id="content")
# ----> 9     job_elems = results.find_all(class_= 'organic-impression display-inline-block listing-link ')
#      10     links_stage = []
#      11    # link_elem = []
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
columns = ['Description','Price','City','State','Region']
listing_data = pd.DataFrame(listing_info,columns=columns)
brooklyn_listings = listing_data
brooklyn_listings.head()
# Out:
#                                          Description  Price      City  \
# 0                      Mauve Pleated Stripe Skirt XS  55.00  Brooklyn
# 1                             Vintage 90s Chic jeans  38.00  Brooklyn
# 2    Vintage Giorgio Armani Blush Pink Womens Blazer  79.99  Brooklyn
# 3  vintage 80’s oversize white cotton chore jacke...  45.00  Brooklyn
# 4                          Ivy Green Leather Skirt M  85.00  Brooklyn
#
#       State      Region
# 0  New York  Eastern US
# 1  New York  Eastern US
# 2  New York  Eastern US
# 3  New York  Eastern US
# 4  New York  Eastern US

# %%
dfs = [oakland_listings, sanfrancisco_listings, santacruz_listings, sacramento_listings, LA_listings, SD_listings, SB_listings, palmsprings_listings]
combined = pd.concat(dfs)
combined.reset_index(inplace=True)

# %%
len(combined)
# Out:
# 10355

# %%
combined.to_csv(r'C:\Users\Starshine1000\desktop\Etsy\CA_listings_22520_notfull.csv')

# %%
dfs = [oakland_listings, sanfrancisco_listings, brooklyn_listings]
largecombined = pd.concat(dfs)
largecombined.reset_index(inplace=True)

# %%
largecombined
# Out:
#        index                                        Description   Price  \
# 0          0          Mickey Mouse Disney 1990's Vintage Tshirt   25.00
# 1          1  Vintage Esprit Pastel Long Sleeve Button Up Pa...   78.95
# 2          2  1910s Art Nouveau Dress | Vintage Teens Edward...  185.00
# 3          3  Vintage 1990s Olive Green Velveteen Quilted Bo...   22.50
# 4          4  vintage | grandma | sweater | 70s | mustard ye...   40.00
# 5          5  Vintage 1950s Ivory Lace Embroidered Floral Bl...   20.00
# 6          6                         Vintage tunic womens dress   15.00
# 7          7  Vintage '60s Vibrant ROSA RAY Chicago Mid Cent...   46.00
# 8          8  vintage 1990s floral skirt / pastel button-up ...   34.00
# 9          9  Candi Jones California  Womens  Boho  Coachell...  100.00
# 10        10                                 vintage 70's dress   20.00
# 11        11  1990's Woman's Vintage 100% Leather Forest Mos...   89.00
